# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Basic Pitch Report

# %% [markdown]
# ### Flute
#
# Average Results:
# Precision: 0.000
# Recall: 0.000
# F1: 0.000
# Onset Precision: 0.206
# Onset Recall: 0.163
# Onset F1: 0.298
# Onset-Offset F1: 0.000

# %%
# compute summaries
df = pd.read_csv("evaluation_results_basic_pitch_flute.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
print(df)
# Out:
#     Precision  Recall   F1  Onset Precision  Onset Recall  Onset F1  \
# 0         0.0     0.0  0.0         0.157895      0.118421  0.236842
# 1         0.0     0.0  0.0         0.278481      0.200000  0.458333
# 2         0.0     0.0  0.0         0.171429      0.139535  0.222222
# 3         0.0     0.0  0.0         0.117647      0.086420  0.184211
# 4         0.0     0.0  0.0         0.191781      0.142857  0.291667
# 5         0.0     0.0  0.0         0.163265      0.181818  0.148148
# 6         0.0     0.0  0.0         0.259740      0.188679  0.416667
# 7         0.0     0.0  0.0         0.285714      0.250000  0.333333
# 8         0.0     0.0  0.0         0.181818      0.127660  0.315789
# 9         0.0     0.0  0.0         0.266667      0.196078  0.416667
# 10        0.0     0.0  0.0         0.280702      0.266667  0.296296
# 11        0.0     0.0  0.0         0.218750      0.155556  0.368421
# 12        0.0     0.0  0.0         0.373333      0.274510  0.583333
# 13        0.0     0.0  0.0         0.281250      0.243243  0.333333
# 14        0.0     0.0  0.0         0.142857      0.098039  0.263158
# 15        0.0     0.0  0.0         0.128205      0.092593  0.208333
# 16        0.0     0.0  0.0         0.153846      0.160000  0.148148
# 17        0.0     0.0  0.0         0.113821      0.082353  0.184211
# 18        0.0     0.0  0.0         0.289855      0.222222  0.416667
# 19        0.0     0.0  0.0         0.310345      0.290323  0.333333
# 20        0.0     0.0  0.0         0.195122      0.141176  0.315789
# 21        0.0     0.0  0.0         0.282051      0.203704  0.458333
# 22        0.0     0.0  0.0         0.250000      0.200000  0.333333
# 23        0.0     0.0  0.0         0.333333      0.288462  0.394737
# 24        0.0     0.0  0.0         0.363636      0.285714  0.500000
# 25        0.0     0.0  0.0         0.274510      0.291667  0.259259
# 26        0.0     0.0  0.0         0.195122      0.141176  0.315789
# 27        0.0     0.0  0.0         0.170732      0.120690  0.291667
# 28        0.0     0.0  0.0         0.296296      0.296296  0.296296
# 29        0.0     0.0  0.0         0.136364      0.095745  0.236842
# 30        0.0     0.0  0.0         0.162791      0.112903  0.291667
# 31        0.0     0.0  0.0         0.250000      0.200000  0.333333
# 32        0.0     0.0  0.0         0.134146      0.087302  0.289474
# 33        0.0     0.0  0.0         0.172043      0.115942  0.333333
# 34        0.0     0.0  0.0         0.243243      0.191489  0.333333
# 35        0.0     0.0  0.0         0.110236      0.078652  0.184211
# 36        0.0     0.0  0.0         0.170213      0.114286  0.333333
# 37        0.0     0.0  0.0         0.177778      0.126984  0.296296
# 38        0.0     0.0  0.0         0.078740      0.056180  0.131579
# 39        0.0     0.0  0.0         0.116279      0.080645  0.208333
# 40        0.0     0.0  0.0         0.333333      0.282051  0.407407
# 41        0.0     0.0  0.0         0.107143      0.081081  0.157895
# 42        0.0     0.0  0.0         0.193548      0.157895  0.250000
# 43        0.0     0.0  0.0         0.271186      0.250000  0.296296
# 44        0.0     0.0  0.0         0.167832      0.114286  0.315789
# 45        0.0     0.0  0.0         0.216216      0.160000  0.333333
# 46        0.0     0.0  0.0         0.317460      0.277778  0.370370
# 47        0.0     0.0  0.0         0.186047      0.131868  0.315789
# 48        0.0     0.0  0.0         0.228571      0.173913  0.333333
# 49        0.0     0.0  0.0         0.315789      0.244898  0.444444
# 50        0.0     0.0  0.0         0.134228      0.090090  0.263158
# 51        0.0     0.0  0.0         0.162791      0.112903  0.291667
# 52        0.0     0.0  0.0         0.375000      0.324324  0.444444
# 53        0.0     0.0  0.0         0.085106      0.058252  0.157895
# 54        0.0     0.0  0.0         0.200000      0.136364  0.375000
# 55        0.0     0.0  0.0         0.000000      0.000000  0.000000
# 56        0.0     0.0  0.0         0.101266      0.072727  0.166667
# 57        0.0     0.0  0.0         0.056338      0.045455  0.074074
#
#     Onset-Offset F1           Filename
# 0               0.0   f1_caro_straight
# 1               0.0   f1_dona_straight
# 2               0.0    f1_row_straight
# 3               0.0   f2_caro_straight
# 4               0.0   f2_dona_straight
# 5               0.0    f2_row_straight
# 6               0.0   f3_dona_straight
# 7               0.0    f3_row_straight
# 8               0.0   f4_caro_straight
# 9               0.0   f4_dona_straight
# 10              0.0    f4_row_straight
# 11              0.0   f5_caro_straight
# 12              0.0   f5_dona_straight
# 13              0.0    f5_row_straight
# 14              0.0   f6_caro_straight
# 15              0.0   f6_dona_straight
# 16              0.0    f6_row_straight
# 17              0.0   f7_caro_straight
# 18              0.0   f7_dona_straight
# 19              0.0    f7_row_straight
# 20              0.0   f8_caro_straight
# 21              0.0   f8_dona_straight
# 22              0.0    f8_row_straight
# 23              0.0   f9_caro_straight
# 24              0.0   f9_dona_straight
# 25              0.0    f9_row_straight
# 26              0.0  m10_caro_straight
# 27              0.0  m10_dona_straight
# 28              0.0   m10_row_straight
# 29              0.0  m11_caro_straight
# 30              0.0  m11_dona_straight
# 31              0.0   m11_row_straight
# 32              0.0   m1_caro_straight
# 33              0.0   m1_dona_straight
# 34              0.0    m1_row_straight
# 35              0.0   m2_caro_straight
# 36              0.0   m2_dona_straight
# 37              0.0    m2_row_straight
# 38              0.0   m3_caro_straight
# 39              0.0   m3_dona_straight
# 40              0.0    m3_row_straight
# 41              0.0   m4_caro_straight
# 42              0.0   m4_dona_straight
# 43              0.0    m4_row_straight
# 44              0.0   m5_caro_straight
# 45              0.0   m5_dona_straight
# 46              0.0    m5_row_straight
# 47              0.0   m6_caro_straight
# 48              0.0   m6_dona_straight
# 49              0.0    m6_row_straight
# 50              0.0   m7_caro_straight
# 51              0.0   m7_dona_straight
# 52              0.0    m7_row_straight
# 53              0.0   m8_caro_straight
# 54              0.0   m8_dona_straight
# 55              0.0   m9_caro_straight
# 56              0.0   m9_dona_straight
# 57              0.0    m9_row_straight

# %% [markdown]
# ### Tenor Saxophone
#
# Average Results:
# Precision: 0.148
# Recall: 0.314
# F1: 0.198
# Onset Precision: 0.337
# Onset Recall: 0.249
# Onset F1: 0.550
# Onset-Offset F1: 0.086

# %%
# compute summaries
df = pd.read_csv("evaluation_results_basic_pitch_tenor_saxophone.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  47.000000  47.000000  47.000000  47.000000        47.000000
# mean    0.147879   0.313514   0.197753   0.549920         0.086262
# std     0.138050   0.287669   0.181135   0.129881         0.095523
# min     0.000000   0.000000   0.000000   0.222222         0.000000
# 25%     0.000000   0.000000   0.000000   0.481481         0.000000
# 50%     0.161905   0.444444   0.239521   0.541667         0.091954
# 75%     0.264914   0.567982   0.366359   0.666667         0.134234
# max     0.358974   0.736842   0.482759   0.750000         0.393939

# %% [markdown]
# ### Trumpet
#
# Average Results:
# Precision: 0.069
# Recall: 0.154
# F1: 0.095
# Onset Precision: 0.295
# Onset Recall: 0.220
# Onset F1: 0.475
# Onset-Offset F1: 0.049

# %%
# compute summaries
df = pd.read_csv("evaluation_results_basic_pitch_trumpet.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  58.000000  58.000000  58.000000  58.000000        58.000000
# mean    0.069058   0.153887   0.094764   0.475499         0.049462
# std     0.114598   0.247267   0.155084   0.157934         0.091491
# min     0.000000   0.000000   0.000000   0.037037         0.000000
# 25%     0.000000   0.000000   0.000000   0.371528         0.000000
# 50%     0.000000   0.000000   0.000000   0.481481         0.000000
# 75%     0.170430   0.411184   0.239076   0.590278         0.064352
# max     0.391304   0.710526   0.504673   0.791667         0.355140

# %% [markdown]
# ### Violin
#
# Average Results:
# Precision: 0.000
# Recall: 0.000
# F1: 0.000
# Onset Precision: 0.278
# Onset Recall: 0.189
# Onset F1: 0.568
# Onset-Offset F1: 0.000

# %%
# compute summaries
df = pd.read_csv("evaluation_results_basic_pitch_violin.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision  Recall    F1   Onset F1  Onset-Offset F1
# count       58.0    58.0  58.0  58.000000             58.0
# mean         0.0     0.0   0.0   0.567907              0.0
# std          0.0     0.0   0.0   0.153777              0.0
# min          0.0     0.0   0.0   0.148148              0.0
# 25%          0.0     0.0   0.0   0.500000              0.0
# 50%          0.0     0.0   0.0   0.578947              0.0
# 75%          0.0     0.0   0.0   0.702303              0.0
# max          0.0     0.0   0.0   0.833333              0.0

# %% [markdown]
# # MT3

# %% [markdown]
# ### Flute
#
# Average Results:
# Precision: 0.002
# Recall: 0.008
# F1: 0.004
# Onset Precision: 0.227
# Onset Recall: 0.160
# Onset F1: 0.456
# Onset-Offset F1: 0.000

# %%
print(df.head())
# Out:
#    Precision    Recall        F1  Onset Precision  Onset Recall  Onset F1  \
# 0   0.000000  0.000000  0.000000         0.256098      0.166667  0.552632
# 1   0.000000  0.000000  0.000000         0.325000      0.232143  0.541667
# 2   0.000000  0.000000  0.000000         0.351648      0.250000  0.592593
# 3   0.000000  0.000000  0.000000         0.175926      0.106742  0.500000
# 4   0.019231  0.041667  0.026316         0.473684      0.346154  0.750000
#
#    Onset-Offset F1          Filename
# 0         0.000000  f1_caro_straight
# 1         0.000000  f1_dona_straight
# 2         0.000000   f1_row_straight
# 3         0.000000  f2_caro_straight
# 4         0.026316  f2_dona_straight

# %%
# compute summaries
df = pd.read_csv("evaluation_results_MT3_flute.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  58.000000  58.000000  58.000000  58.000000        58.000000
# mean    0.002308   0.007864   0.003504   0.455977         0.000477
# std     0.005798   0.018726   0.008642   0.156939         0.002611
# min     0.000000   0.000000   0.000000   0.052632         0.000000
# 25%     0.000000   0.000000   0.000000   0.368908         0.000000
# 50%     0.000000   0.000000   0.000000   0.452851         0.000000
# 75%     0.000000   0.000000   0.000000   0.549890         0.000000
# max     0.025000   0.083333   0.037736   0.777778         0.016949

# %% [markdown]
# ### Tenor Saxophone
#
# Average Results:
# Precision: 0.107
# Recall: 0.249
# F1: 0.145
# Onset Precision: 0.263
# Onset Recall: 0.184
# Onset F1: 0.542
# Onset-Offset F1: 0.074

# %%
# compute summaries
df = pd.read_csv("evaluation_results_MT3_tenor_saxophone.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  47.000000  47.000000  47.000000  47.000000        47.000000
# mean    0.106834   0.248605   0.144501   0.541973         0.073739
# std     0.110630   0.214912   0.138113   0.138697         0.086103
# min     0.000000   0.000000   0.000000   0.315789         0.000000
# 25%     0.007120   0.031676   0.011698   0.432749         0.000000
# 50%     0.080000   0.289474   0.133858   0.552632         0.047059
# 75%     0.187769   0.427388   0.251316   0.627315         0.137934
# max     0.466667   0.625000   0.491228   0.875000         0.350877

# %% [markdown]
# ### Trumpet
#
# Average Results:
# Precision: 0.087
# Recall: 0.174
# F1: 0.114
# Onset Precision: 0.341
# Onset Recall: 0.255
# Onset F1: 0.578
# Onset-Offset F1: 0.067

# %%
# compute summaries
df = pd.read_csv("evaluation_results_MT3_trumpet.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  58.000000  58.000000  58.000000  58.000000        58.000000
# mean    0.086893   0.173628   0.113850   0.578040         0.066945
# std     0.141225   0.266580   0.180430   0.159446         0.122513
# min     0.000000   0.000000   0.000000   0.105263         0.000000
# 25%     0.000000   0.000000   0.000000   0.486111         0.000000
# 50%     0.000000   0.000000   0.000000   0.578947         0.000000
# 75%     0.154866   0.447368   0.236467   0.666667         0.084046
# max     0.472222   0.791667   0.575758   0.875000         0.500000

# %% [markdown]
# ### Violin
#
# Average Results:
# Precision: 0.002
# Recall: 0.004
# F1: 0.002
# Onset Precision: 0.278
# Onset Recall: 0.191
# Onset F1: 0.578
# Onset-Offset F1: 0.000

# %%
# compute summaries
df = pd.read_csv("evaluation_results_MT3_violin.csv")
summary = df.describe()[["Precision", "Recall", "F1", "Onset F1", "Onset-Offset F1"]]
summary
# Out:
#        Precision     Recall         F1   Onset F1  Onset-Offset F1
# count  58.000000  58.000000  58.000000  58.000000        58.000000
# mean    0.001710   0.004420   0.002432   0.577943         0.000454
# std     0.004923   0.012261   0.006914   0.157379         0.003455
# min     0.000000   0.000000   0.000000   0.052632         0.000000
# 25%     0.000000   0.000000   0.000000   0.500000         0.000000
# 50%     0.000000   0.000000   0.000000   0.587963         0.000000
# 75%     0.000000   0.000000   0.000000   0.666667         0.000000
# max     0.019231   0.041667   0.026316   0.916667         0.026316

# %% [markdown]
# # Results Interpretation Figures

# %%
# -----------------------------------------------------------
# Performance Analysis of Timbre-Transferred Audio
# -----------------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from math import pi

# Configure plotting aesthetics
sns.set(style="whitegrid", context="talk", font_scale=0.9)

# -----------------------------------------------------------
# 1. Load all model results
# -----------------------------------------------------------
models = ["MT3", "basic_pitch"]
instruments = ["flute", "trumpet", "tenor_saxophone", "violin"]

all_results = []

for model in models:
    for inst in instruments:
        fname = f"evaluation_results_{model}_{inst}.csv"
        if os.path.exists(fname):
            df = pd.read_csv(fname)
            df["Model"] = model
            df["Instrument"] = inst.capitalize().replace("_", " ")
            all_results.append(df)

# Combine all into one DataFrame
results = pd.concat(all_results, ignore_index=True)

# -----------------------------------------------------------
# 2. Compute average metrics per instrument & model
# -----------------------------------------------------------
metrics = ["Precision", "Recall", "F1", "Onset Precision", "Onset Recall", "Onset F1", "Onset-Offset F1"]
avg_results = results.groupby(["Model", "Instrument"])[metrics].mean().reset_index()

# Save the table for reference
avg_results.to_csv("timbre_transfer_summary.csv", index=False)
print(avg_results)

# -----------------------------------------------------------
# 3. Bar Plots: F1 and Onset F1 across instruments
# -----------------------------------------------------------
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_results, x="Instrument", y="F1", hue="Model")
plt.title("F1-Score Across Timbre-Transferred Instruments")
plt.ylabel("Average F1-Score")
plt.xlabel("Instrument")
plt.legend(title="Model")
plt.tight_layout()
plt.savefig("F1_across_instruments.png", dpi=300)
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_results, x="Instrument", y="Onset F1", hue="Model")
plt.title("Onset F1 Across Timbre-Transferred Instruments")
plt.ylabel("Average Onset F1")
plt.xlabel("Instrument")
plt.legend(title="Model")
plt.tight_layout()
plt.savefig("Onset_F1_across_instruments.png", dpi=300)
plt.show()

# -----------------------------------------------------------
# 4. Violin Plots: Distribution of F1 and Onset F1
# -----------------------------------------------------------
plt.figure(figsize=(10, 6))
sns.boxplot(data=results, x="Instrument", y="F1", hue="Model", palette="coolwarm")
plt.title("Distribution of F1-Scores Across Timbre-Transferred Audio")
plt.ylabel("F1-Score")
plt.xlabel("Instrument")
plt.tight_layout()
plt.savefig("F1_distribution_violin.png", dpi=300)
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(data=results, x="Instrument", y="Onset F1", hue="Model", split=True, inner="quart")
plt.title("Distribution of Onset F1 Across Timbre-Transferred Audio")
plt.ylabel("Onset F1")
plt.xlabel("Instrument")
plt.tight_layout()
plt.savefig("Onset_F1_distribution_violin.png", dpi=300)
plt.show()

# -----------------------------------------------------------
# 5. Heatmap: Correlation among metrics (for each model)
# -----------------------------------------------------------
for model in results["Model"].unique():
    plt.figure(figsize=(8, 6))
    corr = results[results["Model"] == model][metrics].corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title(f"Metric Correlation Heatmap – {model}")
    plt.tight_layout()
    plt.savefig(f"heatmap_correlation_{model}.png", dpi=300)
    plt.show()

# -----------------------------------------------------------
# 6. Radar Plot: Per-instrument performance profile
# -----------------------------------------------------------
def radar_plot(data, title):
    categories = list(data.columns[2:])  # Skip Model & Instrument
    N = len(categories)

    for i, row in data.iterrows():
        values = row[categories].values.flatten().tolist()
        values += values[:1]  # Close the circle
        angles = [n / float(N) * 2 * pi for n in range(N)]
        angles += angles[:1]

        plt.figure(figsize=(6, 6))
        ax = plt.subplot(111, polar=True)
        plt.xticks(angles[:-1], categories, color='grey', size=8)
        ax.plot(angles, values, linewidth=2, linestyle='solid', label=row["Model"])
        ax.fill(angles, values, alpha=0.3)
        plt.title(f"{row['Instrument']} ({row['Model']})", size=12, pad=20)
        plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
        plt.tight_layout()
        plt.savefig(f"radar_{row['Model']}_{row['Instrument'].replace(' ', '_')}.png", dpi=300)
        plt.close()

# Generate radar plots
radar_plot(avg_results, "Instrument-wise Performance Profiles")

# -----------------------------------------------------------
# 7. Optional: Table display formatting for publication
# -----------------------------------------------------------
formatted_table = avg_results.copy()
formatted_table[metrics] = formatted_table[metrics].applymap(lambda x: f"{x:.3f}")
print("\nFormatted Summary Table for Publication:\n")
print(formatted_table.to_markdown(index=False))
# Out:
#          Model       Instrument  Precision    Recall        F1  \
# 0          MT3            Flute   0.002308  0.007864  0.003504
# 1          MT3  Tenor saxophone   0.106834  0.248605  0.144501
# 2          MT3          Trumpet   0.086893  0.173628  0.113850
# 3          MT3           Violin   0.001710  0.004420  0.002432
# 4  basic_pitch            Flute   0.000000  0.000000  0.000000
# 5  basic_pitch  Tenor saxophone   0.147879  0.313514  0.197753
# 6  basic_pitch          Trumpet   0.069058  0.153887  0.094764
# 7  basic_pitch           Violin   0.000000  0.000000  0.000000
#
#    Onset Precision  Onset Recall  Onset F1  Onset-Offset F1
# 0         0.227260      0.160400  0.455977         0.000477
# 1         0.262686      0.184109  0.541973         0.073739
# 2         0.340811      0.255090  0.578040         0.066945
# 3         0.278192      0.190671  0.577943         0.000454
# 4         0.205722      0.163101  0.298166         0.000000
# 5         0.336991      0.249409  0.549920         0.086262
# 6         0.294679      0.219581  0.475499         0.049462
# 7         0.277829      0.188891  0.567907         0.000000
# Formatted Summary Table for Publication:
#
# | Model       | Instrument      |   Precision |   Recall |    F1 |   Onset Precision |   Onset Recall |   Onset F1 |   Onset-Offset F1 |
# |:------------|:----------------|------------:|---------:|------:|------------------:|---------------:|-----------:|------------------:|
# | MT3         | Flute           |       0.002 |    0.008 | 0.004 |             0.227 |          0.16  |      0.456 |             0     |
# | MT3         | Tenor saxophone |       0.107 |    0.249 | 0.145 |             0.263 |          0.184 |      0.542 |             0.074 |
# | MT3         | Trumpet         |       0.087 |    0.174 | 0.114 |             0.341 |          0.255 |      0.578 |             0.067 |
# | MT3         | Violin          |       0.002 |    0.004 | 0.002 |             0.278 |          0.191 |      0.578 |             0     |
# | basic_pitch | Flute           |       0     |    0     | 0     |             0.206 |          0.163 |      0.298 |             0     |
# | basic_pitch | Tenor saxophone |       0.148 |    0.314 | 0.198 |             0.337 |          0.249 |      0.55  |             0.086 |
# | basic_pitch | Trumpet         |       0.069 |    0.154 | 0.095 |             0.295 |          0.22  |      0.475 |             0.049 |
# | basic_pitch | Violin          |       0     |    0     | 0     |             0.278 |          0.189 |      0.568 |             0     |
# /var/folders/97/rcp_v2wx559bpmg158hjmtgh0000gn/T/ipykernel_8495/1763942203.py:131: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   formatted_table[metrics] = formatted_table[metrics].applymap(lambda x: f"{x:.3f}")

# %%
# Transpose so metrics are rows and models are columns
import pandas as pd

# Load your CSV file
results = pd.read_csv("transcription_summary.csv")

# Define metrics
metrics = ["Precision", "Recall", "F1", "Onset Precision", "Onset Recall", "Onset F1", "Onset-Offset F1"]

# Compute mean results by Model and Instrument
avg_results = results.groupby(["Model", "Instrument"])[metrics].mean().reset_index()

# Reshape so metrics become rows and Model/Instrument stay as columns
metrics_as_rows = (
    avg_results.melt(id_vars=["Model", "Instrument"], var_name="Metric", value_name="Value")
    .pivot_table(index="Metric", columns=["Model", "Instrument"], values="Value")
)

# Optional: display or save to file
metrics_as_rows

# To save to CSV:
# metrics_as_rows.to_csv("metrics_as_rows.csv")
# Out:
# Model                 MT3                                     basic_pitch  \
# Instrument          Flute Tenor saxophone   Trumpet    Violin       Flute
# Metric
# F1               0.003504        0.144501  0.113850  0.002432    0.000000
# Onset F1         0.455977        0.541973  0.578040  0.577943    0.298166
# Onset Precision  0.227260        0.262686  0.340811  0.278192    0.205722
# Onset Recall     0.160400        0.184109  0.255090  0.190671    0.163101
# Onset-Offset F1  0.000477        0.073739  0.066945  0.000454    0.000000
# Precision        0.002308        0.106834  0.086893  0.001710    0.000000
# Recall           0.007864        0.248605  0.173628  0.004420    0.000000
#
# Model
# Instrument      Tenor saxophone   Trumpet    Violin
# Metric
# F1                     0.197753  0.094764  0.000000
# Onset F1               0.549920  0.475499  0.567907
# Onset Precision        0.336991  0.294679  0.277829
# Onset Recall           0.249409  0.219581  0.188891
# Onset-Offset F1        0.086262  0.049462  0.000000
# Precision              0.147879  0.069058  0.000000
# Recall                 0.313514  0.153887  0.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv("transcription_summary.csv")

# The metric columns in the file
metrics = [
    'Precision',
    'Recall',
    'F1',
    'Onset Precision',
    'Onset Recall',
    'Onset F1',
    'Onset-Offset F1'
]

# Melt wide → long
df_long = df.melt(
    id_vars=['Model', 'Instrument'],
    value_vars=metrics,
    var_name='Metric',
    value_name='Score'
)

# We allow zeros here (so basic_pitch still shows up); just drop NaN if any
df_long = df_long.dropna(subset=['Score', 'Model', 'Instrument'])

# Average score per (Model, Instrument, Metric)
summary = (
    df_long
    .groupby(['Model', 'Instrument', 'Metric'], as_index=False)['Score']
    .mean()
)

# Order models explicitly: basic_pitch on top, MT3 on bottom
models_order = ['basic_pitch', 'MT3']

# Consistent instrument ordering in the legend
instrument_order = sorted(summary['Instrument'].unique())

sns.set_theme(style="whitegrid")

# One subplot per model, stacked vertically
fig, axes = plt.subplots(
    nrows=2,
    ncols=1,
    figsize=(12, 10),
    sharex=True,
    sharey=True
)

for ax, model in zip(axes, models_order):
    model_data = summary[summary['Model'] == model]

    # Plot bar chart: x = Metric, grouped bars = Instrument
    sns.barplot(
        data=model_data,
        x='Metric',
        y='Score',
        hue='Instrument',
        hue_order=instrument_order,
        errorbar=None,               # seaborn 0.11: disables CI bars
        ax=ax
    )

    ax.set_title(f"{model.title() if model == 'basic_pitch' else model} Mean Performance Across Instruments", fontsize=14)
    ax.set_ylabel("Score", fontsize=12)
    ax.set_ylim(0, 1)          # compare systems on same scale
    ax.set_xlabel("")          # we'll label x only on bottom plot
    ax.legend(title="Instrument", loc="upper right")

# Bottom subplot gets the x-axis label
axes[-1].set_xlabel("Metric", fontsize=12)

plt.tight_layout()
plt.show()
