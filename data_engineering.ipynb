# %%
# Raw files data engineering
import pandas as pd
import shutil
import pretty_midi

# %%
def generate_midi(df_rows, file_name, save_path="dataset/midi/"):
    # Create PrettyMIDI object
    midi = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(program=0)  # piano=0, voice_oohs=53, lead_6=85

    for _, row in df_rows.iterrows():
        note_type = str(row[" Type"]).strip()
        if note_type == "Sound":
            start = float(row[" Start time"])
            end = float(row[" End time"])
            pitch = int(row[" Estimated MIDI code"]) # int(row[" Ground Truth MIDI code"])
            # pitch = pretty_midi.note_name_to_number(row[" Ground truth Note name"]) # Retrieve the MIDI note number for this note name
            velocity = 100

            note = pretty_midi.Note(
                velocity=velocity,
                pitch=pitch,
                start=start,
                end=end
            )
            instrument.notes.append(note)

    midi.instruments.append(instrument)

    # Save to MIDI file
    midi_path = save_path + file_name + ".mid"
    midi.write(midi_path)

    return midi_path

# %%
# Move wav files to dataset path
def copy_wav_files(file_name, root="/Users/martinoywa/Downloads/VocalSet/FULL/", save_path="dataset/wav/"): # TODO replace with ~/Downloads/VocalSet/FULL
    file_name_split = file_name.split("_")

    if "m" in file_name_split[0]:
        parent = "male" + file_name_split[0][1]
    else:
        parent = "female" + file_name_split[0][1]

    old_path = root + parent + "/" + "/".join(file_name_split[1:-1]) + "/" + file_name + ".wav"
    new_path = save_path + file_name + ".wav"
    shutil.copy(old_path, new_path)

    return new_path

# %%
def generate_dataset(annotated_dataset_path="dataset/raw"):
    """
    Uses raw data to generate midi version of the dataset.
    Returns a dataframe of metadata.
    Columns: wav filepath, midi filepath

    :param annotated_dataset_path:
    :return:
    """
    # metadata
    metadata = {"filename": [], "midi": [], "wav": []}

    # read data and join all data
    df = pd.read_csv("dataset/raw/extended_1_all_files.csv", index_col=False) # TODO write join functionality

    # filter for straight only
    df_straights_filtered = df[df['File Name'].str.contains("straight", case=False, na=False)]

    # extract unique file names data for processing
    unique_file_names = df_straights_filtered['File Name'].unique()

    # generate midi file and copy wav file
    for file_name in unique_file_names:
        rows = df_straights_filtered[df_straights_filtered['File Name'] == file_name]
        try: # TODO, Missing .wav files still get generated .midi files. Check below and dataset folder
            midi_path, wav_path = generate_midi(rows, file_name), copy_wav_files(file_name)
            metadata["filename"].append(file_name)
            metadata["midi"].append(midi_path)
            metadata["wav"].append(wav_path)
        except FileNotFoundError:
            print(f"File {file_name} not found")

    return metadata

# %%
metadata = generate_dataset(annotated_dataset_path="dataset/raw")
metadata = pd.DataFrame(metadata, columns=["filename", "midi", "wav"])
metadata.to_csv("dataset/raw/metadata.csv", index=False)
# Out:
# File f1_caro_straight not found
# File f1_dona_straight not found
# File f1_long_straight_a not found
# File f1_long_straight_e not found
# File f1_long_straight_i not found
# File f1_long_straight_o not found
# File f1_long_straight_u not found
# File f1_row_straight not found
# File f2_caro_straight not found
# File f2_dona_straight not found
# File f2_long_straight_a not found
# File f2_long_straight_e not found
# File f2_long_straight_i not found
# File f2_long_straight_o not found
# File f2_long_straight_u not found
# File f2_row_straight not found
# File f3_dona_straight not found
# File f3_long_straight_a not found
# File f3_long_straight_e not found
# File f3_long_straight_i not found
# File f3_long_straight_o not found
# File f3_long_straight_u not found
# File f3_row_straight not found
# File f4_caro_straight not found
# File f4_dona_straight not found
# File f4_long_straight_a not found
# File f4_long_straight_e not found
# File f4_long_straight_i not found
# File f4_long_straight_o not found
# File f4_long_straight_u not found
# File f4_row_straight not found
# File f5_caro_straight not found
# File f5_dona_straight not found
# File f5_long_straight_a not found
# File f5_long_straight_e not found
# File f5_long_straight_i not found
# File f5_long_straight_o not found
# File f5_long_straight_u not found
# File f5_row_straight not found
# File f6_caro_straight not found
# File f6_dona_straight not found
# File f6_long_straight_a not found
# File f6_long_straight_e not found
# File f6_long_straight_i not found
# File f6_long_straight_o not found
# File f6_long_straight_u not found
# File f6_row_straight not found
# File f7_caro_straight not found
# File f7_dona_straight not found
# File f7_long_straight_a not found
# File f7_long_straight_e not found
# File f7_long_straight_i not found
# File f7_long_straight_o not found
# File f7_long_straight_u not found
# File f7_row_straight not found
# File f8_caro_straight not found
# File f8_dona_straight not found
# File f8_long_straight_a not found
# File f8_long_straight_e not found
# File f8_long_straight_i not found
# File f8_long_straight_o not found
# File f8_long_straight_u not found
# File f8_row_straight not found
# File f9_caro_straight not found
# File f9_dona_straight not found
# File f9_long_straight_a not found
# File f9_long_straight_e not found
# File f9_long_straight_i not found
# File f9_long_straight_o not found
# File f9_long_straight_u not found
# File f9_row_straight not found
# File m10_arpeggios_straight_a not found
# File m10_arpeggios_straight_e not found
# File m10_arpeggios_straight_i not found
# File m10_arpeggios_straight_o not found
# File m10_arpeggios_straight_u not found
# File m10_caro_straight not found
# File m10_dona_straight not found
# File m10_long_straight_a not found
# File m10_long_straight_e not found
# File m10_long_straight_i not found
# File m10_long_straight_o not found
# File m10_long_straight_u not found
# File m10_row_straight not found
# File m10_scales_straight_a not found
# File m10_scales_straight_e not found
# File m10_scales_straight_i not found
# File m10_scales_straight_o not found
# File m10_scales_straight_u not found
# File m11_arpeggios_straight_a not found
# File m11_arpeggios_straight_e not found
# File m11_arpeggios_straight_i not found
# File m11_arpeggios_straight_o not found
# File m11_arpeggios_straight_u not found
# File m11_caro_straight not found
# File m11_dona_straight not found
# File m11_long_straight_a not found
# File m11_long_straight_e not found
# File m11_long_straight_i not found
# File m11_long_straight_o not found
# File m11_long_straight_u not found
# File m11_row_straight not found
# File m11_scales_straight_a not found
# File m11_scales_straight_e not found
# File m11_scales_straight_i not found
# File m11_scales_straight_u not found
# File m1_caro_straight not found
# File m1_dona_straight not found
# File m1_long_straight_a not found
# File m1_long_straight_e not found
# File m1_long_straight_i not found
# File m1_long_straight_o not found
# File m1_long_straight_u not found
# File m1_row_straight not found
# File m1_straight_tone_scales_u not found
# File m2_caro_straight not found
# File m2_dona_straight not found
# File m2_long_straight_a not found
# File m2_long_straight_e not found
# File m2_long_straight_i not found
# File m2_long_straight_o not found
# File m2_long_straight_u not found
# File m2_row_straight not found
# File m3_caro_straight not found
# File m3_dona_straight not found
# File m3_long_straight_a not found
# File m3_long_straight_e not found
# File m3_long_straight_i not found
# File m3_long_straight_o not found
# File m3_long_straight_u not found
# File m3_row_straight not found
# File m4_caro_straight not found
# File m4_dona_straight not found
# File m4_long_straight_a not found
# File m4_long_straight_e not found
# File m4_long_straight_i not found
# File m4_long_straight_o not found
# File m4_long_straight_u not found
# File m4_row_straight not found
# File m5_caro_straight not found
# File m5_dona_straight not found
# File m5_long_straight_a not found
# File m5_long_straight_e not found
# File m5_long_straight_i not found
# File m5_long_straight_o not found
# File m5_long_straight_u not found
# File m5_row_straight not found
# File m6_caro_straight not found
# File m6_dona_straight not found
# File m6_long_straight_a not found
# File m6_long_straight_e not found
# File m6_long_straight_i not found
# File m6_long_straight_o not found
# File m6_long_straight_u not found
# File m6_row_straight not found
# File m7_caro_straight not found
# File m7_dona_straight not found
# File m7_long_straight_e not found
# File m7_long_straight_i not found
# File m7_long_straight_o not found
# File m7_long_straight_u not found
# File m7_row_straight not found
# File m8_caro_straight not found
# File m8_dona_straight not found
# File m8_long_straight_a not found
# File m8_long_straight_e not found
# File m8_long_straight_i not found
# File m8_long_straight_o not found
# File m8_long_straight_u not found
# File m9_caro_straight not found
# File m9_dona_straight not found
# File m9_long_straight_e not found
# File m9_long_straight_i not found
# File m9_long_straight_o not found
# File m9_long_straight_u not found
# File m9_row_straight not found

# %%
# TODO Missing: Long, Row, Caro. What are these?
